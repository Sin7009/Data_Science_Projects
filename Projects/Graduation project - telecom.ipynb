# %% [markdown]
# <h1> Комментарий тимлида </h1>
#
# 👋 **Привет, Константин!**
#
# ✨ Поздравляю с началом работы над финальным проектом!
#
# Меня зовут Арсен Абдулин и я буду проверять твою работу. Предлагаю общаться на «ты», если не против=)
#
# При проверке работ я пишу следующие комментарии:
#
# <div class='alert alert-success'>
# <b>✔️ Зеленым цветом</b> отмечены удачные решения.</div>
#
# <div class='alert alert-warning'>
# <b>⚠️ Желтым цветом</b> я отметил пункты, которые в следующий раз можно сделать по-другому. Одно-два таких замечания в проекте допускается, но если их много — проект следует доработать. </div>
#
# <div class='alert alert-danger'>
# <b>🚫 Красным цветом</b> отмечены критические замечания, которые необходимо поправить, чтобы принять проект. </div>
#
# Если какие-то моменты в задании для тебя были непонятны и у тебя есть ко мне вопросы — смело спрашивай 😊 Также ты можешь доработать места, где есть желтые комментарии в проекте (однако, это не обязательно).
#
# Предлагаю работать в диалоге: если ты решишь что-то поменять по моим рекомендациям — пиши об этом (выбери для своих комментариев определенный цвет - так мне будет легче увидеть изменения). Пожалуйста не перемещай, не изменяй и не удаляй мои комментарии. Все это поможет сделать проверку твоего проекта оперативнее.
#
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b> Пример комментария. </div>

# %% [markdown]
# # Телеком — задача проекта
#
# Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.
#
# ### Описание услуг
#
# Оператор предоставляет два основных типа услуг:
#
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 2. Интернет. Подключение может быть двух типов: через телефонную линию (DSL*,* от англ. *digital subscriber line*, «цифровая абонентская линия») или оптоволоконный кабель (*Fiber optic*).
#
# Также доступны такие услуги:
#
# - Интернет-безопасность: антивирус (*DeviceProtection*) и блокировка небезопасных сайтов (*OnlineSecurity*);
# - Выделенная линия технической поддержки (*TechSupport*);
# - Облачное хранилище файлов для резервного копирования данных (*OnlineBackup*);
# - Стриминговое телевидение (*StreamingTV*) и каталог фильмов (*StreamingMovies*).
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.
#
# ### Описание данных
#
# Данные состоят из файлов, полученных из разных источников:
#
# - `contract.csv` — информация о договоре;
# - `personal.csv` — персональные данные клиента;
# - `internet.csv` — информация об интернет-услугах;
# - `phone.csv` — информация об услугах телефонии.
#
# Во всех файлах столбец `customerID` содержит код клиента.
#
# Информация о договорах актуальна на 1 февраля 2020.

# %% [markdown]
# ## Цель проекта:
# научиться прогнозировать отток клиентов оператора связи "Ниединогоразрыва.ком", используя данные о договорах, персональных данных клиентов и информации об услугах.

# %% [markdown]
# <div class='alert alert-warning'>
# <b>⚠️ Комментарий тимлида:</b> Здорово, что ты сформулировал цель проекта!
#
# Нужно также добавить название проекта и небольшое описание
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b> Сделано! :) </div>

# %% [markdown]
# <div class='alert alert-success'>
# <b>✔️ Комментарий тимлида v2:</b> Хорошо, так гораздо лучше!
#
# </div>

# %% [markdown]
# ## Примерный план решения задачи:
#
# * Загрузка данных, разведывательный анализ данных.
# * Объединение таблиц в один дата фрейм.
# * Предобработка данных.
# * Добавление целевого показателя.
# * Исследовательский анализ данных, в том числе:
#     * Проверка на мультиколлинеарность и обработка данных (при необходимости удаление 'протекающих' данных).
# * Подбор гиперпараметров моделей.
# * Тестирование лучшей модели.

# %% [markdown]
# <div class='alert alert-success'>
# <b>✔️ Комментарий тимлида:</b> В целом план работ последовательный и понятный, все хорошо!
#
# Есть некоторые рекомендации и уточнения:
#
# 1. Исследовательский анализ делаем после создания новых признаков
#
# 2. На тестовой выборке проверяем только одну лучшую модель
#
# Советую дождаться вебинара, возможно план немного поменяется.
#
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b> Жду вебинар :) </div>

# %% [markdown]
# <div class='alert alert-success'>
# <b>✔️ Комментарий тимлида v2:</b> Поправь пожалуйста план работы с учетом рекомендаций, которые были на вебинаре и еще нужно добавить выводы после изучения данных
#
# После этого можно будет приступать к основной части проекта
#
# </div>

# %% [markdown]
# ## Загрузка данных, разведывательный анализ данных.

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий тимлида:</b> В ячейке ниже возникает ошибка при перезапуске кода, поправь пожалуйста
#
# Нужно добавить библиотеки imblearn, tabulate
#
# Установки библиотек лучше вынести в отдельную ячейку
# </div>

# %%
# !pip install -U phik
# !pip install -U scikit-learn
# !pip install -U matplotlib
# !pip install -U seaborn
# !pip install -U scikit-optimize
# !pip install -U plotly
# !pip install -U imblearn
# !pip install -U tabulate

# %%
RANDOM_STATE = 130323


import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import phik
import lightgbm as lgb
import catboost

from imblearn.under_sampling import RandomUnderSampler
from sklearn.preprocessing import OneHotEncoder
from plotly.subplots import make_subplots
from lightgbm import LGBMClassifier
from scipy import stats
from phik.report import plot_correlation_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split, RandomizedSearchCV, GridSearchCV, cross_val_predict
from sklearn.metrics import roc_auc_score, accuracy_score, roc_curve
from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

from tabulate import tabulate

from sklearn.model_selection import StratifiedKFold

cv_strategy = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)

scoring = ['roc_auc', 'accuracy', 'f1']

# %%
try:
    contract = pd.read_csv('contract.csv')
except:
    contract = pd.read_csv('/datasets/final_provider/contract.csv')
try:
    internet = pd.read_csv('internet.csv')
except:
    internet  = pd.read_csv('/datasets/final_provider/internet.csv')
try:
    phone = pd.read_csv('phone.csv')
except:
    phone = pd.read_csv('/datasets/final_provider/phone.csv')
try:
    personal = pd.read_csv('personal.csv') 
except:
    personal = pd.read_csv('/datasets/final_provider/personal.csv')

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b> Арсен, посмотри, пожалуйста, можно ли так сделать в данном случае? Или я делаю что-то не так?</div>

# %% [markdown]
# <div class='alert alert-warning'>
# <b>⚠️ Комментарий тимлида:</b> Вообще желательно сначала датасеты исследовать по отдельности, прежде чем объединять.
#
# В любом случае, нужно написать вывод на основе загруженных данных, поэтому пока что отправлю план на доработку
#
# </div>

# %%
contract.info()

# %%
contract.head()

# %%
contract.describe()

# %%
contract.hist()

# %%
internet.info()

# %%
internet.head()

# %%
internet.describe()

# %%
phone.info()

# %%
phone.head()

# %%
phone.describe()

# %%
personal.info()

# %%
personal.head()

# %%
personal.describe()

# %%
personal.hist()

# %% [markdown]
# ### Вывод по разведывательным данным
# Описание основных столбцов:
#
# * BeginDate – дата начала пользования услугами,
# * EndDate – дата окончания пользования услугами,
# * Type – тип оплаты: ежемесячный, годовой и тд,
# * PaperlessBilling – безналичный расчет,
# * PaymentMethod – способ оплаты,
# * MonthlyCharges – ежемесячные траты на услуги,
# * TotalCharges – всего потрачено денег на услуги
# * Dependents – наличие иждивенцев
# * Senior Citizen – наличие пенсионного статуса по возрасту
# * Partner – наличие супруга(и)
# * MultipleLines – наличие возможности ведения параллельных линий во время
# звонка
#
#
# Какие проблемы в данных замечены?
#
# * Необходимо присвоить столбцам правильные типы данных.
# * Нужна проверка на пропуски, аномалии, неизвестные значения

# %% [markdown]
# ## Список уточняющих вопросов к тимлиду:
#
# Вопросов не имею :)

# %% [markdown]
# <div class='alert alert-success'>
# <b>✔️ Комментарий тимлида:</b> На самом деле на эти вопросы я отвечу на предстоящем вебинаре
#
# - все признаки могут быть важными, но некоторые признаки дадут утечку, например даты подключения;
#
# - это твоя задача в исследовательском анализе
#
# - нужно будет проверить :)
#
# - пропуски и аномалии ты также должен сам найти, если они есть
#
# - мы рассматриваем как минимум две модели, например бустинг и случайный лес. Лучше конечно рассмотреть три модели, например добавить логистическую регрессию
#
# Лучшую модель проверяем на тестовой выборке
#
# </div>

# %% [markdown]
# <div class='alert alert-success'>
# <b>✔️ Комментарий тимлида v3:</b> План работ принят, можно приступать к основному проекту.
#
# Пожалуйста сохрани наши с тобой комментарии, а проект продолжай делать в этом же документе, успехов!
#
# </div>

# %% [markdown]
# <h1> Комментарий ревьювера </h1>
#
# <div class="alert alert-success">
#
# 👋 Константин, привет еще раз! Это снова Арсен Абдулин — и я буду делать ревью основного проекта.
#
# Давай посмотрим, что получилось.
#
# </div>

# %% [markdown]
# # Предобработка данных

# %% [markdown]
# ## Объединие данных в один дата фрейм

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Общая рекомендация по проекту:
#
# - желательно не перегружать код подробными комментариями. Если делаешь это для себя, то в рамках учебного проекта допустимо, но лучше комментировать только особо важные и непонятные места
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Общая рекомендация по проекту:
#
# - комментарии к текущим действиям необходимо писать в ячейках Markdown, т.к. наш проект по сути является отчетом =)
#
# В комментариях с ячейками кода обычно пишут особенности выполнения кода.
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий тимлида:</b> Желательно придерживаться стандарта PEP-8:
#
# https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html
#
# Строки должны умещаться в ширину страницы, например:
#
#     df = pd.merge(
#         contract, internet, how='left', on='customerID'
#     ).merge(
#         personal, how='left',  on='customerID'
#     ).merge(
#         phone, how='left', on='customerID'
#     )
#
# </div>

# %%
df = pd.merge(
    contract, internet, how='left', on='customerID'
).merge(personal, how='left',  on='customerID'
       ).merge(phone, how='left', on='customerID'
)

df.set_index('customerID', inplace=True)

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b> Поправил и сделал customerID индексом</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Хорошо!
#
#
# </div>

# %% [markdown]
# ## Проверка на пропуски

# %%
pd.DataFrame(round(df.isna().mean()*100)).style.background_gradient('coolwarm').format('{:.0f}%')

# %% [markdown]
# Пропуски есть в первую очередь в таблице internet (столбцы InternetService, OnlineSecurity, OnlineBackup, DeviceProtection, TechSupport, StreamingTV, StreamingMovies) все по 22%. Скорее всего эти пропуски вызваны тем, что эти клиенты не пользуются интернет услугами.
#
# В столбце MultipleLines (относится к телефону) отсутствуют 10% данных, скорее всего это эти клиенты не пользуются телефонными услугами.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Все правильно, если клиент не пользуется какой-либо услугой, то его нет в соответствующей таблице
#
# </div>

# %% [markdown]
# ## Заполнение пропусков

# %%
df['InternetService'] = df['InternetService'].fillna('No')
df['OnlineSecurity'] =df['OnlineSecurity'].fillna('No')
df['OnlineBackup'] = df['OnlineBackup'].fillna('No')
df['DeviceProtection'] = df['DeviceProtection'].fillna('No')
df['TechSupport'] = df['TechSupport'].fillna('No')
df['StreamingTV'] = df['StreamingTV'].fillna('No')
df['StreamingMovies'] = df['StreamingMovies'].fillna('No')
df['MultipleLines'] = df['MultipleLines'].fillna('No')

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Заполнение пропусков выполнено успешно!
#
# </div>

# %% [markdown]
# ## Создание целевой переменной

# %%
df['target'] = df['EndDate'].apply(lambda val: 0 if val == 'No' else 1)

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера:</b> Необходимо инвертировать целевую переменную
#
# Факт оттока клиента это значение — 1
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b> Тут я что-то поплыл, но исправил :)</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Обычно в задачах классификации малый класс обозначают единицей, а оставшиеся значения — 0.
#
# Например, задача найти негативный отзыв или отточного клиента. Естественно, что таких негативных примеров должно быть меньше, чем нейтральных.
#
# Поэтому мы говорим, что если модель выдает положительный результат, то клиент склонен к оттоку или получили негативный отзыв.
#
# </div>

# %% [markdown]
# ## Перевод столбцов в нужный тип данных

# %%
df.loc[df['EndDate'] == 'No', 'EndDate'] = pd.to_datetime('2020-02-01')

# %%
df['BeginDate'] = pd.to_datetime(df['BeginDate'])
df['EndDate'] = pd.to_datetime(df['EndDate'])

df['DaysWithCompany'] = (df['EndDate'] - df['BeginDate']).dt.days

df['SeniorCitizen'] = df['SeniorCitizen'].apply(lambda val: 'Yes' if val == 1 else 'No')

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Отлично, получили целевую переменную!
#
# </div>

# %%
# Вычисление разности между датами начала и окончания контракта в месяцах
months_between_dates = (df['EndDate'].dt.year - df['BeginDate'].dt.year) * 12 + \
                        (df['EndDate'].dt.month - df['BeginDate'].dt.month)
                        
# Замена пустых значений в столбце TotalCharges на произведение MonthlyCharges и количества месяцев
df.loc[df['TotalCharges'] == ' ', 'TotalCharges'] = \
    df['MonthlyCharges'] * months_between_dates

df['TotalCharges'] = df['TotalCharges'].astype(float)

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Если удаляешь некоторые строки, то нужно проверить, какой % данных мы потеряли?
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b> Решил не удалять данные, а просто поправить их.</div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Понял тебя, хорошо
#
# На самом деле удаление допускается, если таких данных немного — нужно только проверить этот момент
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b> Там было 15% незаполненных строк только по этому столбцу, но так как я не использую его в моделях, я решил заполнить его, а не удалять, и не терять данные. .</div>

# %% [markdown]
# ## Проверка данных после обработки

# %%
df.head(20)

# %%
df.info()

# %%
df.duplicated().sum()

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Если решил проверить дубликаты, то лучше customerID сделать индексом
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b> Сделал чуть раньше </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Хорошо!
# </div>

# %% [markdown]
# # Исследовательский анализ данных

# %% [markdown]
# Создадим новый датафрейм специально для исследовательского анализа данных

# %%
df_for_plot = df.copy()

df_for_plot['begin_date'] = pd.to_datetime(df['BeginDate']).dt.date
df_for_plot['end_date'] = pd.to_datetime(df['EndDate']).dt.date
df_for_plot = df_for_plot.drop(columns=['BeginDate', 'EndDate'])

df_for_plot['year_end'] = pd.DatetimeIndex(df_for_plot['end_date']).year
df_for_plot['year_begin'] = pd.DatetimeIndex(df_for_plot['begin_date']).year

df_for_plot['User_Status'] = df_for_plot['target'].map({0: 'Current User', 1: 'Former User'})

# %%
df_for_plot.info()

# %% [markdown]
# Посмотрим ящики с усами для цифровых значений:

# %%
fig = px.box(df_for_plot, y='MonthlyCharges')
fig.update_traces(marker_color='red', marker_size=3, line_width=2)
fig.update_layout(title='Ежемесячные расходы')

fig2 = px.box(df_for_plot, y='TotalCharges')
fig2.update_traces(marker_color='blue', marker_size=3, line_width=2)
fig2.update_layout(title='Общие расходы')

fig.show()
fig2.show()

# %% [markdown]
# 1.  Средний ежемесячный платеж составляет примерно $65, а средние общие затраты - около $2283.
#
# 2.  Есть большой разброс значений в ежемесячных платежах и общих затратах, что указывает на то, что у компании есть клиенты с разными потребностями и бюджетами.
#
# 3.  Минимальный ежемесячный платеж составляет $18.25, а максимальный - $118.75. Минимальные общие затраты составляют $18.8, а максимальные - $8684.8.
#
# 4.  25% клиентов имеют ежемесячный платеж менее $35.6, а 50% клиентов - менее $70.35.
#
# 5.  75% клиентов имеют ежемесячный платеж менее $89.86, а 50% клиентов - менее $1397.48.
#
# 6.  Общие затраты (TotalCharges) имеют более широкий диапазон значений, чем ежемесячные платежи, что может быть связано с длительностью использования услуг.
#
# 7.  Стандартное отклонение общих затрат выше, чем стандартное отклонение ежемесячных платежей, что также может указывать на больший разброс этих значений.

# %%
count_user = df_for_plot.groupby('year_begin')['MonthlyCharges'].count().sort_values()

fig = px.bar(df_for_plot, x=count_user.index, y=count_user.values, color=count_user)

fig.update_layout(title='Количество новых пользователей',
                   xaxis_title='Количество',
                   yaxis_title='Год',
                   width=800, height=600)
fig.show()

# %% [markdown]
# Наибольшее число новых пользователей пришло в 2019 году (1957 клиентов). Второй (по численности) прирост был в 2014 (1344).
#
# В 2013 году было только 8 новых клиентов. Возможно это был тестовый запуск или запуск для компаний.

# %% [markdown]
# Посмотрим сколько в среднем платят клиенты присоединившееся к компании в разные годы:

# %%
mean_monthly_charges = df_for_plot.groupby('year_begin')['MonthlyCharges'].mean()

fig = go.Figure()
fig.add_trace(go.Bar(x=mean_monthly_charges.index, y=mean_monthly_charges.values, opacity=0.5, marker_color='red'))
for year, mean_charge in mean_monthly_charges.items():
    fig.add_annotation(x=year, y=mean_charge, text=f'{mean_charge:.2f}', showarrow=True, font=dict(size=14))
fig.update_layout(title='Зависимость ежемесячных платежей от года начала использования услуг',
                  xaxis_title='Год начала использования услуг',
                  yaxis_title='Ежемесячный платеж',
                  width=800, height=600)
pio.show(fig)

# %% [markdown]
# Чем позднее клиент присоединялся к компании, тем меньше он платил ежемесячно.
#
# Те кто начали пользоваться услугами в 2013 в среднем платили по 100 у.е. за услуги. В 2013 году таких клиентов было всего 8, что не является достаточным для точного определения. Однако начиная с 2014 года существует устойчивая тенденция к снижению среднемесечного платежа у новых клиентов.
#
# Посмотрим, кто сколько платит в зависимости от типа оплаты:

# %%
mean_monthly_charges = df_for_plot.groupby('PaymentMethod')['MonthlyCharges'].mean().sort_values()

fig = px.bar(df_for_plot, x=mean_monthly_charges.index, y=mean_monthly_charges.values, color=mean_monthly_charges)

fig.update_layout(title='Средний ежемесячный платёж и типу оплаты',
                   xaxis_title='Тип оплаты',
                   yaxis_title='Средний ежемесячный платёж',
                   width=800, height=600)
fig.show()

# %% [markdown]
# Самый большой средний чек у тех клиентов, что предпочитают электронные чеки. Меньше всего платят те, которые посылают чеки по почте. Возможно это пенсионеры?

# %%
fig = px.histogram(df_for_plot, x='SeniorCitizen', color='PaymentMethod',
                   title='Связь между возрастом и типом оплаты',
                   labels={'SeniorCitizen': 'Является ли клиент пожилым?', 'PaymentMethod': 'Тип оплаты'},
                   nbins=2)

fig.show()

# %% [markdown]
# Нет, пожилые клиенты, наоборот, пользуются услугами электронной оплаты.

# %% [markdown]
# Перейдем к категориальным признакам (Красный цвет - бывший клиент, Синий цвет - текущий клиент):

# %%
fig = make_subplots(rows=3, cols=5, subplot_titles=('Тип оплаты', 'Безбумажная оплата', 'Способ оплаты', 
                                                     'Интернет-сервис', 'Онлайн-безопасность',
                                                     'Резервное копирование онлайн', 'Защита устройства', 
                                                     'Техническая поддержка', 'Потоковое телевидение', 
                                                     'Потоковое кино', 'Пол', 'Пожилой клиент', 
                                                     'Супружество', 'Наличие иждивенцев', 'Несколько линий'))

for i, column in enumerate(['Type', 'PaperlessBilling', 'PaymentMethod', 'InternetService', 'OnlineSecurity',
                             'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
                             'gender', 'SeniorCitizen', 'Partner', 'Dependents', 'MultipleLines']):
    data = df_for_plot.groupby('User_Status')[column].value_counts().unstack()
    
    fig.add_trace(go.Bar(x=data.columns, y=data.loc['Former User'], name='Бывший клиент', marker_color='Red'),
                  row=(i // 5) + 1, col=(i % 5) + 1)
    
    fig.add_trace(go.Bar(x=data.columns, y=data.loc['Current User'], name='Текущий клиент', marker_color='Blue'),
                  row=(i // 5) + 1, col=(i % 5) + 1)
    
    fig.update_traces(selector=dict(name='Бывший клиент'), showlegend=False)
    fig.update_traces(selector=dict(name='Текущий клиент'), showlegend=False)

fig.update_xaxes(showticklabels=True)
fig.update_yaxes(showticklabels=True)
fig.update_layout(height=1000, width=1200, title_text='Категориальные переменные', barmode='stack')

fig.show()

# %% [markdown]
# Те кто оплачивают подписку на услуги сразу на год или два вперед гораздо реже уходят, чем те кто платит ежемесячно.
#
# Так же те клиенты, у которых подключены дополнительные услуги, такие как онлайн-безопасность, Резервное копирование онлайн, Защита устройства, и Техническая поддержка, так же реже покидают компанию по сравнению с теми кто этими услугами не пользуется.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Хороший анализ данных, все понятно и очень подробно =)
#
# Здорово, что подробно исследовал влияние каждого признака на отток!
#
# Нужно только помнить, что влияние различных факторов на целевую переменную, это гипотеза, и нужно использовать методы проверки гипотез. Но это уже отдельная работа =)
#
# </div>

# %% [markdown]
# ### Проверка цифровых значений на мультиколлениарность

# %%
corr_matrix = df.corr()
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

# %%
sns.scatterplot(x='MonthlyCharges', y='TotalCharges', data=df)
plt.show()

# %%
r_squared = stats.linregress(df['MonthlyCharges'], df['TotalCharges']).rvalue**2
print(f"R²: {r_squared}")

p_value = stats.linregress(df['MonthlyCharges'], df['TotalCharges']).pvalue
print(f"p-value: {p_value}")

# %% [markdown]
# 1.  Значение R² равно 0.42, что означает, что приблизительно 42% дисперсии в TotalCharges могут быть объяснены линейной зависимостью между MonthlyCharges и TotalCharges.
#
# 2.  Значение p-value равно 0.0, что говорит о том, что нулевая гипотеза "коэффициент наклона равен нулю (то есть, что нет линейной зависимости между MonthlyCharges и TotalCharges)", может быть отвергнута на уровне значимости 0.05 (или любом другом выбранном уровне значимости). То есть, между MonthlyCharges и TotalCharges есть статистически значимая линейная зависимость.
#
# Таким образом, можно заключить, что между MonthlyCharges и TotalCharges есть линейная зависимость, которая объясняет приблизительно 42% дисперсии в TotalCharges. При этом, эта зависимость статистически значима.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Здорово, что проверил статистическую значимость взаимосвязи признаков! Как вариант, можно было проверить связь с целевой переменной
#
# Желательно еще отметить, что у признаков TotalCharges и длительностью контракта есть сильная взаимосвязь, коэффициент корреляции гораздо выше чем у признаков, которые ты рассмотрел
#
# </div>

# %% [markdown]
# ## Проверка на мультиколлениарность с помощью phik

# %%
phik_matrix = df.phik_matrix(interval_cols=('MonthlyCharges', 'TotalCharges', 'target'))
plot_correlation_matrix(phik_matrix.values, 
                        x_labels=phik_matrix.columns, 
                        y_labels=phik_matrix.index, 
                        vmin=0, vmax=1, 
                        color_map='coolwarm', 
                        title=r'Корреляции', 
                        fontsize_factor=0.7, 
                        figsize=(10, 10))
plt.tight_layout()

# %%
high_corr_pairs = phik_matrix[phik_matrix > 0.8].stack()
print(high_corr_pairs)

# %% [markdown]
# На основе матрицы корреляции можно заметить, что есть некоторая мультиколлинеарность между признаками. Например, сильная корреляция между 'MonthlyCharges' и 'InternetService', 'TotalCharges' и 'BeginDate'.
#
# Для устранения мультиколлинеарности можно удалить один из пары сильно коррелирующих признаков или объединить их в один новый признак.
#
# В данном случае, можно удалить 'TotalCharges'. А так же 'BeginDate' и'EndDate' (Целевая переменная 'target' была создана на основе признака 'EndDate'), а 'BeginDate' была использована для создания 'DaysWithCompany'.

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Предлагаю убрать в выводе корреляцию с begin_date, т.к. это все-таки производный признак, на основе которого посчитана длительность контракта
#
# Лучше указать, что есть корреляция общих платеежей и длительности контракта клиента
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера v2:</b> Все-таки я пока не увидел в выводе, что есть корреляция TotalCharges и DaysWithCompany =)
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b> Сделано! :) </div>

# %%
df = df.drop(['TotalCharges', 'BeginDate','EndDate'], axis=1)

# %% [markdown]
# ### Вывод по Исследовательскому анализу данных.
#
# 1.  Средний ежемесячный платеж и средние общие затраты находятся на умеренном уровне, что может свидетельствовать о конкурентоспособности компании в отношении стоимости услуг.
#
# 2.  Большой разброс значений ежемесячных платежей и общих затрат указывает на наличие клиентов с разными потребностями и бюджетами.
#
# 3.  Минимальные и максимальные значения ежемесячных платежей и общих затрат также имеют широкий разброс, что подтверждает разнообразие клиентской базы.
#
# 4.  Более чем 25% клиентов имеют ежемесячный платеж менее $35.6, что может быть интересным для компании, и нужно рассмотреть возможность предложения определенных услуг для привлечения большего числа клиентов.
#
# 5.  75% клиентов имеют ежемесячный платеж менее $89.86, что также может помочь компании определить ценообразование и стратегию продаж.
#
# 6.  Общие затраты имеют более широкий диапазон значений, чем ежемесячные платежи, что может объясняться длительностью использования услуг.
#
# 7.  Стандартное отклонение общих затрат выше, чем стандартное отклонение ежемесячных платежей, что также может указывать на больший разброс этих значений.
#
# 8.  Прирост числа клиентов был наибольшим в 2019 году, что может свидетельствовать об успешных маркетинговых кампаниях или новых продуктах/услугах.
#
# 9.  Существует устойчивая тенденция к снижению среднемесечного платежа у новых клиентов, начиная с 2014 года.
#
# 10. Клиенты, которые оплачивают подписку на услуги за год или два вперед, реже покидают компанию, чем те, кто платит ежемесячно. Также клиенты, которые используют дополнительные услуги, такие как онлайн-безопасность, Резервное копирование онлайн, Защита устройства и Техническая поддержка, реже уходят из компании. Это может быть полезной информацией для компании при формировании своей стратегии удержания клиентов.
#
# 11. По итогу мультиколлинеарного анализа было удалено 4 столбца: 'customerID', 'TotalCharges', 'gender', 'begin_date' и 'end_date'

# %% [markdown]
# # Подбор гиперпараметров моделей

# %% [markdown]
# 1.  Закодировать категориальные признаки методом OneHotEncoding.
#
# 2.  Разделить данные на тренировочный и тестовый наборы с помощью функции train_test_split() из библиотеки sklearn.model_selection. Указать размер тестовой выборки равным 0.25.
#
# 3.  Создать как минимум две модели машинного обучения, например, случайный лес и градиентный бустинг. Обучить модели на тренировочном наборе данных и оценить их производительность на тестовом наборе данных по метрикам AUC-ROC и Accuracy.
#
# 4.  Проверить производительность каждой модели на кросс-валидации и выбрать лучшую модель на основе метрики AUC-ROC.
#
# 5.  Оценить производительность лучшей модели на тестовом наборе данных, чтобы проверить ее способность обобщения на новые данные.
#
# 6.  Использовать критерии оценки, установленные заказчиком: AUC-ROC >= 0.85.
#
# 7.  При анализе результатов обратить внимание на переобучение моделей и выбрать ту модель, которая показывает лучшие результаты на тестовом наборе данных и при этом не переобучена.
#
# 8.  Дополнительно можно применять методы для настройки параметров моделей, такие как GridSearchCV или RandomizedSearchCV, чтобы оптимизировать производительность модели.

# %%
X = df.drop(['target'], axis=1)
y = df['target']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=RANDOM_STATE)

# %%
class_count = y.value_counts()

print(f'Количество объектов класса 0: {class_count[0]}')
print(f'Количество объектов класса 1: {class_count[1]}')
print(f'Отношение классов: {class_count[0] / class_count[1]:.2f}')

# %%
rus = RandomUnderSampler(random_state=RANDOM_STATE)

X_train, y_train = rus.fit_resample(X_train, y_train)

# %%
cat_features = ['Type', 'PaperlessBilling', 'PaymentMethod', 'InternetService',
                'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
                'StreamingTV', 'StreamingMovies', 'SeniorCitizen', 'Partner', 
                'Dependents', 'MultipleLines','gender']

# %%
num_features = ['MonthlyCharges', 'DaysWithCompany']

# %%
# Создаем объект OneHotEncoder с нужными параметрами
ohe_enc = OneHotEncoder(sparse_output=False, drop = 'first', handle_unknown='ignore')

# Обучаем энкодер на обучающих данных
ohe_enc.fit(X_train[cat_features])

# Получаем имена новых признаков
new_columns = ohe_enc.get_feature_names_out(cat_features)

# Кодируем категориальные признаки и создаем датафреймы с новыми именами признаков
X_train_cat_ohe = ohe_enc.transform(X_train[cat_features])
X_test_cat_ohe = ohe_enc.transform(X_test[cat_features])
X_train_cat_df = pd.DataFrame(X_train_cat_ohe, columns=new_columns)
X_test_cat_df = pd.DataFrame(X_test_cat_ohe, columns=new_columns)

# Объединяем закодированные категориальные и числовые признаки
# Заполняем пропущенные значения в числовых признаках
imputer = SimpleImputer(strategy='median')
X_train_num_imputed = imputer.fit_transform(X_train[num_features])
X_test_num_imputed = imputer.transform(X_test[num_features])

# Создаем датафреймы с категориальными и заполненными числовыми признаками
X_train_processed = pd.concat([X_train_cat_df, pd.DataFrame(X_train_num_imputed, columns=num_features)], axis=1)
X_test_processed = pd.concat([X_test_cat_df, pd.DataFrame(X_test_num_imputed, columns=num_features)], axis=1)

print(f"Размерности обучающей выборки: {X_train_processed.shape}")
print(f"Размерности тестовой выборки: {X_test_processed.shape}")

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера v3:</b> В энкодере нужно указать параметр
#
#     drop = 'first'
#
# Иначе после кодирования остаются лишние колонки, в которых избыточная информация
#
# </div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера v2:</b> Есть еще один момент в кодировании, который стоит поправить:
#
# - в твоем случае теряются имена признаков и если мы потом будем исследовать их значимость, то будет непонятно влияние каждого признака.
#
# Нужно из энкодера получить имена новых признаков:
#
#     new_columns = ohe_enc.get_feature_names(cat_features)
#
# Далее тебе нужно создать датафрейм уже с новыми названиями признаков — пример есть в Пачке, посмотри пожалуйста
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b>  Вроде сделал, надеюсь правильно </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера:</b> Мы должны обучать любой энкодер только на выборке train, иначе будет утечка
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b>  Сделал </div>

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера:</b> Scaler нужно обучать только на выборке train
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b>  Сделал </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Хорошо, все теперь правильно
#
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Не советую удалять так много признаков на начальном этапе
#
# Не совсем понятно, почему выбран порог значимость 0,03? На самом деле при исследовании значимости признаков, это некий безразмерный параметр, но он не связан с корреляцией.
#
# Еще стоит отметить, что для разных моделей, например catboost и randomforest, значимость признаков может быть разная
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b>  Я так увидел, пока шестерил интернет, и "обезьянка видит - обезьянка делает" Убрал этот кусок полностью. </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> На самом деле действительно можно выбрать только значимые признаки, но выбранный порог в 0.03 отсекал слишком много признаков. Как вариант, можно было оставить топ-10 или топ-15.
#
# </div>

# %%
lr = LogisticRegression(random_state=RANDOM_STATE, penalty='l2', solver='lbfgs', max_iter=1000, fit_intercept=False)
rf = RandomForestClassifier(random_state=RANDOM_STATE)
gb = GradientBoostingClassifier(random_state=RANDOM_STATE)
lgbm = LGBMClassifier(random_state=RANDOM_STATE)
catboost = CatBoostClassifier(random_state=RANDOM_STATE, verbose=0)

y_proba_lr = cross_val_predict(lr, X_train_processed, y_train, cv=cv_strategy, method='predict_proba')[:, 1]
y_proba_rf = cross_val_predict(rf, X_train_processed, y_train, cv=cv_strategy, method='predict_proba')[:, 1]
y_proba_gb = cross_val_predict(gb, X_train_processed, y_train, cv=cv_strategy, method='predict_proba')[:, 1]
y_proba_lgbm = cross_val_predict(lgbm, X_train_processed, y_train, cv=cv_strategy, method='predict_proba')[:, 1]
y_proba_catboost = cross_val_predict(catboost, X_train_processed, y_train, cv=cv_strategy, method='predict_proba')[:, 1]

roc_auc_lr = roc_auc_score(y_train, y_proba_lr)
roc_auc_rf = roc_auc_score(y_train, y_proba_rf)
roc_auc_gb = roc_auc_score(y_train, y_proba_gb)
roc_auc_lgbm = roc_auc_score(y_train, y_proba_lgbm)
roc_auc_catboost = roc_auc_score(y_train, y_proba_catboost)

print(f"Logistic Regression ROC-AUC score: {roc_auc_lr:.2f}")
print(f"Random Forest ROC-AUC score: {roc_auc_rf:.2f}")
print(f"Gradient Boosting ROC-AUC score: {roc_auc_gb:.2f}")
print(f"LGBM ROC-AUC score: {roc_auc_lgbm:.2f}")
print(f"CatBoost ROC-AUC score: {roc_auc_catboost:.2f}")

# %% [markdown]
# Был вычислен ROC-AUC для 5 различных моделей машинного обучения: логистической регрессии (LogisticRegression), случайного леса (RandomForestClassifier), градиентного бустинга (GradientBoostingClassifier), LGBM-модели (LGBMClassifier) и CatBoost-модели (CatBoostClassifier).
#
# Выводы:
#
# *   Наилучшее значение ROC-AUC (0.88) было получено с помощью CatBoost-модели, LGBM-модели и градиентного бустинга.
# *   ROC-AUC для логистической регрессии также достаточно высок (0.84), но ниже, чем у других моделей кроме модели случайного леса (0.83).
#
# Таким образом, все модели показали хорошие результаты в задаче классификации, но лучшую производительность продемонстрировала CatBoost-модель. Однако, чтобы выбрать наилучшую модель, необходимо не только оценить качество предсказаний, но также учитывать другие факторы, например, скорость обучения и простоту интерпретации модели.

# %% [markdown]
# ### LogisticRegression

# %% [markdown]
# <div class="alert alert-danger">
# <b>🚫 Комментарий ревьювера:</b> Для линейных моделей необходимо использовать OHE кодирование. Пример есть в Пачке
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b>  Сделал </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Хорошо
#
# </div>

# %%
param_grid = {'C': [0.0001, 0.001, 0.01, 0.1, 1, 10, 100]}

lr_search = GridSearchCV(lr, param_grid, cv=cv_strategy)

lr_search.fit(X_train_processed, y_train)

lr_best_params = lr_search.best_params_

y_proba = lr_search.predict_proba(X_test_processed)[:, 1]

lr_roc_auc = roc_auc_score(y_test, y_proba)

print(f"Тип модели: {type(lr)}")
print(f"Лучшие параметры: {lr_best_params}")
print(f"ROC-AUC score: {lr_roc_auc:.2f}")

# %% [markdown]
# ### RandomForestClassifier

# %%
param_grid = {'n_estimators': [1, 50, 100],
              'max_depth': [1, 5, 10]
}

rf_search = GridSearchCV(rf, param_grid, cv=cv_strategy)

rf_search.fit(X_train_processed, y_train)

rf_best_params = rf_search.best_params_

y_proba = rf_search.predict_proba(X_test_processed)[:, 1]

rf_roc_auc = roc_auc_score(y_test, y_proba)

print(f"Тип модели: {type(rf)}")
print(f"Лучшие параметры: {rf_best_params}")
print(f"ROC-AUC score: {rf_roc_auc:.2f}")

# %% [markdown]
# ### GradientBoostingClassifier

# %%
param_grid = {'learning_rate': [0.01, 0.05, 0.1, 0.15],
              'n_estimators': [50, 100, 200, 500],
              'max_depth': [3, 5, 7]
}

gb_search = RandomizedSearchCV(gb,
                                 param_distributions=param_grid,
                                 scoring=scoring,
                                 cv=cv_strategy,
                                 refit='roc_auc')

gb_search.fit(X_train_processed, y_train)

gb_best_params = gb_search.best_params_

y_proba = gb_search.predict_proba(X_test_processed)[:, 1]

gb_roc_auc = roc_auc_score(y_test, y_proba)

print(f"Тип модели: {type(gb)}")
print(f"Лучшие параметры: {gb_best_params}")
print(f"ROC-AUC score: {gb_roc_auc:.2f}")

# %% [markdown]
# ### LGBM

# %%
param_grid = {'learning_rate': [0.01, 0.05, 0.1, 0.15],
              'n_estimators': [50, 100, 200, 500],
              'max_depth': [3, 5, 7]
}

lgbm_search = RandomizedSearchCV(lgbm,
                                 param_distributions=param_grid,
                                 scoring=scoring,
                                 cv=cv_strategy,
                                 refit='roc_auc')

lgbm_search.fit(X_train_processed, y_train)

lgbm_best_params = lgbm_search.best_params_

y_proba = lgbm_search.predict_proba(X_test_processed)[:, 1]

lgbm_roc_auc = roc_auc_score(y_test, y_proba)

print(f"Тип модели: {type(lgbm)}")
print(f"Лучшие параметры: {lgbm_best_params}")
print(f"ROC-AUC score: {lgbm_roc_auc:.2f}")

# %% [markdown]
# ### CatBoostClassifier

# %%
param_grid = {'learning_rate': [0.005, 0.01, 0.05, 0.1, 0.15],
              'n_estimators': [50, 100, 200, 500, 1000],
              'max_depth': [3, 5, 7, 9, 11]
}

catboost_search = RandomizedSearchCV(catboost,
                                 param_distributions=param_grid,
                                 scoring=scoring,
                                 cv=cv_strategy, verbose=0,
                                 refit='roc_auc')

catboost_search.fit(X_train_processed, y_train)

catboost_best_params = catboost_search.best_params_

y_proba = catboost_search.predict_proba(X_test_processed)[:, 1]

catboost_roc_auc = roc_auc_score(y_test, y_proba)

print(f"Тип модели: {type(catboost)}")
print(f"Лучшие параметры: {catboost_best_params}")
print(f"ROC-AUC score: {catboost_roc_auc:.2f}")

# %%
model_comparison = pd.DataFrame({
    'Модель': ['Logistic Regression', 'Random Forest', 'Gradient Boosting', 'LGBM', 'Catboost'],
    'Лучшие параметры': [lr_best_params, rf_best_params, gb_best_params, lgbm_best_params, catboost_best_params],
    'ROC-AUC': [lr_roc_auc, rf_roc_auc, gb_roc_auc, lgbm_roc_auc, catboost_roc_auc]
})

model_comparison_sorted = model_comparison.sort_values(by='ROC-AUC', ascending=False)
print(tabulate(model_comparison_sorted, headers='keys', tablefmt='fancy_grid', showindex=False))

# %% [markdown]
# Из таблицы сравнения моделей видно, что три модели - Gradient Boosting, Catboost и LGBM - имеют значение метрики ROC-AUC более 0.89, что говорит о хорошей способности этих моделей различать положительные и отрицательные классы на данных.
#
# Лучшая модель Gradient Boosting  имеет значение ROC-AUC около 0.909 и показывает лучший результат по сравнению с другими моделями.
#
# Следующей по качеству является модель LGBM  c ROC-AUC около 0.892.
#
# Модель Catboost также демонстрирует хороший результат с ROC-AUC около 0.870.
#
# Модели Random Forest и Logistic Regression имеют наименьшее значение ROC-AUC из всех моделей в данном сравнении.
#
# Таким образом, для решения задачи классификации следует выбрать одну из трех лучших моделей: Gradient Boosting, Catboost или LGBM. Выбор конкретной модели зависит от соответствия ее свойствами требованиям проекта и заключительной оценки качества после тестирования на новых данных.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Здорово, что рассмотрел несколько моделей и сделал перебор гиперпараметров!
#
# Видно, что проделана большая работа, обучение моделей выполнено правильно
#
# </div>

# %% [markdown]
# # Тестирование лучшей модели на тестовой выборке

# %%
best_model = GradientBoostingClassifier(**gb_best_params)

best_model.fit(X_train_processed, y_train)

y_proba_test = best_model.predict_proba(X_test_processed)[:, 1]

best_model_roc_auc_test = roc_auc_score(y_test, y_proba_test)

fpr, tpr, thresholds = roc_curve(y_test, y_proba_test)
fig = make_subplots(rows=1, cols=1)
fig.add_trace(go.Scatter(x=fpr, y=tpr, mode='lines', name='ROC curve'), row=1, col=1)
fig.add_trace(go.Scatter(x=[0, 1], y=[0, 1], mode='lines', line=dict(dash='dash'), showlegend=False), row=1, col=1)
fig.update_xaxes(title_text='False Positive Rate', row=1, col=1)
fig.update_yaxes(title_text='True Positive Rate', row=1, col=1)
fig.update_layout(title={'text': f'ROC Curve (Test Sample) - Gradient Boosting Classifier <br> ROC AUC Score: {best_model_roc_auc_test:.2f}',
                          'font': {'size': 16},
                          'x': 0.5,
                          'xanchor': 'center'},
                  legend={'x': 0.7, 'y': 0.2})
fig.show()

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Метрика ROC-AUC > 0.85, поздравляю!
#
# </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера:</b> Желательно добавить график ROC-кривой для лучшей модели
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b>  Добавил! </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера:</b> Вот небольшие статьи по метрикам в машинном обучении, если заинтересует:
#
# https://habr.com/ru/company/ods/blog/328372/
#
# https://habr.com/ru/company/jetinfosystems/blog/420261/
#
# </div>

# %% [markdown]
# Результаты тестирования лучшей модели, Gradient Boosting Classifier, на тестовой выборке показывают, что модель имеет ROC-AUC score 0.92, что означает хорошую способность различать положительные и отрицательные классы на данных. Значение accuracy score на тестовой выборке равно 0.82, что говорит о том, что модель правильно классифицировала 82% случаев.
#
# Таким образом, результаты тестирования подтверждают, что Gradient Boosting Classifier является эффективной моделью для решения задачи классификации в данном проекте и может быть использована для предсказания классов новых данных с высокой точностью. Однако, как и при использовании любой модели машинного обучения, необходимо учитывать особенности данных и контекста применения модели, а также проводить регулярную проверку ее качества на новых данных, чтобы убедиться в ее актуальности и эффективности.

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v2:</b> Осталось поправить кодирование признаков, в остальном все хорошо
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b>  Надеюсь, что сделал правильно! </div>

# %% [markdown]
# <div class="alert alert-warning">
# <b>⚠️ Комментарий ревьювера v3:</b> В энкодере нужно добавить параметр drop = 'first'
#
# </div>

# %% [markdown]
# <div class='alert alert-info'> <b>ℹ️ Комментарий студента: </b>  Поправил :) </div>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v4:</b> Отлично, теперь все правильно!
#
# </div>

# %% [markdown]
# <font color=blue>
# <b> ✔️ 👍Заключение ревьювера:</b> Константин, было приятно проверять твою работу, она выполнена на хорошем уровне и практически завершена!
#
# В целом тебе удалось справиться с проектом, поздравляю! Данные из разных таблиц собраны в один датафрейм, удалены аномалии, заполнены пропуски, получены новые признаки, а ненужные признаки удалены. Рассмотрено несколько моделей и сделан перебор параметров. Могу отметить самостоятельность и аналитический подход в выполнении проекта!
#
# Положительные моменты:
#
# - грамотное и понятное оформление кода;
#
# - аналитический подход — исследованы распределения признаков, проведен подробный анализ;
#
# - новые признаки сгенерированы правильно, лишние удалены;
#
# - рассмотрены несколько моделей и сделан перебор гиперпараметров, удалось достичь высокого значения метрики ROC-AUC.
#
# Сейчас есть несколько важных замечаний:
#
# - добавить установку необходимых библиотек;
#
# - инвертировать целевую переменную;
#
# - для линейных моделей нужно сделать OHE-кодирование;
#
# - поправить кодирование и масштабирование признаков.
#
# На данном этапе проект практически завершен, я также отметил рекомендации. Поскольку ты рано подготовил проект, у нас еще есть время — я отправлю его, чтобы ты мог ознакомиться с проверкой, внести изменения и возможно задать вопросы =)
#
# Также на будущее стоит иметь ввиду, что метрика ROC-AUC является не единственной, всегда нужно прислушиваться к требованиями бизнеса. Обычно одной метрикой не ограничиваются, смотрят также Precision, Recall, и выбирают те, которые наиболее подходят для конкретных задач.
#
# Еще нужно смотреть на важность признаков в модели, чтобы понимать, какие параметры влияют на отток.
#
# Проверка важности признаков по модели это только один из способов (корреляция в том числе). Используют также аналитические методы проверки гипотез.
#
# </font>

# %% [markdown]
# <div class="alert alert-success">
# <b>✔️ Комментарий ревьювера v4:</b> Константин, поздравляю с выполнением основной части проекта!
#
# Пожалуйста, сохрани наши с тобой комментарии, а отчет продолжай выполнять ниже, в этом файле Jupyter Notebook.
#
# В отчете не забудь указать все пункты по предобработке данных, параметрам модели, набору признаков для обучения — чтобы была возможность воспроизвести твою работу, изучив только отчет.
#
# Необходимо выделить следующие пункты:
#
# - список признаков, которые использовались для обучения;
#
# - указать итоговую модель и ее гиперпараметры — желательно в отдельной строке, чтобы не сливалась с остальным текстом;
#
# - отличия от исходного плана работ;
#
# - в отчете нужно указать трудности в работе (если не было, то так и написать) и ключевые этапы (если ключевых этапов не было, то написать, что все этапы важны);
#
# - размер тестовой выборки, параметр random_state.
#
# Я принимаю работу и буду ждать твой отчет на проверку!
#
# </div>
